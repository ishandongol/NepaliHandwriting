# %% [markdown]
# <h1> Introduction </h1>

# %% [markdown]
# In this project, we trained a CNN classifier using Keras.Our strategy will be using 20% of the train data as a validation set to optimize the classifier, while keeping test data to finally evaluate the accuracy of the model on the data it has never seen.

# %% [markdown]
# <h1> Architecture </h1>

# %% [markdown]
# The architecture showing different layers and nodes of our model is as follows
# <img src="graph.png" />

# %% [markdown]
# The basic architecture of the model can be described by the summary of model below:

# %%
from keras.models import load_model
model = load_model("cnn_handwriting_110_inv.h5")
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 36, 36, 36)        360
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 36)        11700
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 17, 17, 36)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17, 17, 36)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 17, 17, 72)        23400
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 15, 15, 72)        46728
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 72)          0
# ...

# %% [markdown]
# <h1> Training </h1>

# %% [markdown]
# We trained our model using fit() function. The fit() will return a History object which we can use to plot training vs. validation accuracy and loss. The parameters used during training are as follows:

# %%
Parameters = {
    "lr":0.001,
    "epoch" : 20,
    "batch_size" : 110,
    "optimizer" : "adam",
    "loss":"categorical_crossentropy",
    "image_dim":36
}

# %% [markdown]
# The loss and accuracy during training are as follows:

# %% [markdown]
# <h3> Comparison between Training Loss and Validation Loss </h3>

# %% [markdown]
# <img src="loss.png" />
# <div>
# <h4>Label :</h4>
#     <font size = "6" color='gray'>----</font> : Training
#     <br>
#     <font size = "6" color='orange'>----</font> : Validation
# <h4> Axes :</h4>
#     Xlabel : epochs
#     <br>
#     Ylable : loss
# </div>

# %% [markdown]
# <h3> Comparison between Training Accuracy and Validation Accuracy </h3>

# %% [markdown]
# <img src="accuracy.png" />
# <div>
# <h4>Label :</h4>
#     <font size = "6" color='gray'>----</font> : Training
#     <br>
#     <font size = "6" color='orange'>----</font> : Validation
# <h4> Axes :</h4>
#     Xlabel : epochs
#     <br>
#     Ylable : accuracy
# </div>

# %% [markdown]
# <h1> Results </h1>

# %% [markdown]
# We can summarize the performance of our classifier as follows

# %%
import pandas as pd
report = pd.read_csv("report.csv",delimiter=",")
report
# Out:
#       Class  precision  recall  f1-score  support
# 0         ०       0.96    0.96      0.96      300
# 1         १       0.94    0.83      0.88      300
# 2         २       0.67    0.57      0.62      300
# 3         ३       0.94    0.85      0.89      300
# 4         ४       0.91    0.96      0.94      300
# 5         ५       0.72    0.95      0.82      300
# 6         ६       0.82    0.86      0.84      300
# 7         ७       0.97    0.87      0.92      300
# 8         ८       0.94    0.83      0.88      300
# 9         ९       0.77    0.91      0.84      300
# 10        अ       0.00    0.00      0.00        0
# 11        आ       0.00    0.00      0.00        0
# 12        इ       0.00    0.00      0.00        0
# 13        ई       0.00    0.00      0.00        0
# 14        उ       0.00    0.00      0.00        0
# 15        ऊ       0.00    0.00      0.00        0
# 16        ए       0.00    0.00      0.00        0
# 17        ऐ       0.00    0.00      0.00        0
# ...

# %% [markdown]
# It's apparent that our classifier is underperforming for class 2 in terms of both precision and recall. For class 38 and class 39, classifier is slightly lacking precision whereas it is slightly lacking recall for class 2.
#
# Perhaps we would gain more insight after visualizing the correct and incorrect predictions.

# %% [markdown]
# Here is a subset of correctly predicted classes. The below figure contains 9 exapmle of correctly predicted classes.

# %% [markdown]
# <img src="correct.png" style="float:left;"/>

# %% [markdown]
# And here is a subset of incorrectly predicted classes.

# %% [markdown]
# <img src="incorrect.png" style="float:left;"/>

# %% [markdown]
# <h1> Conclusion </h1>

# %% [markdown]
# It has been great journey learning ML and DL.!
